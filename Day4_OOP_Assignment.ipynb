# %% [markdown]
# # Day 4 Assignment – Object-Oriented Programming (OOP)
#
# Name: Jay Joshi

# %% [markdown]
# ## Introduction to Object-Oriented Programming (OOP)
#
# Object-Oriented Programming (OOP) is a programming paradigm that organizes code into classes and objects. It helps developers create reusable, scalable, and maintainable software. OOP is based on concepts such as encapsulation, inheritance, polymorphism, and abstraction. These concepts allow programs to model real-world entities and improve code organization.

# %% [markdown]
# # Theory Notes

# %% [markdown]
# ### Classes and Objects
#
# A class is a blueprint for creating objects. It defines the attributes and methods that an object will have. An object is an instance of a class. Classes help organize data and behavior into reusable structures. Object-Oriented Programming uses classes and objects to model real-world entities.

# %%
class Student:
    pass

s1 = Student()

print(type(s1))
# Out:
# <class '__main__.Student'>

# %% [markdown]
# ### Constructors (__init__)
#
# A constructor is a special method that is automatically called when an object is created. In Python, the constructor is written using the __init__() method. It is used to initialize object attributes.

# %%
class Student:

    def __init__(self, name):
        self.name = name

s1 = Student("Jay")

print(s1.name)
# Out:
# Jay

# %% [markdown]
# ### Instance Variables and Methods
#
# Instance variables belong to an object and store its data. Instance methods operate on the object's data and use the self parameter to access instance variables.

# %%
class Student:

    def __init__(self, name):
        self.name = name

    def display(self):
        print(self.name)

s1 = Student("Jay")
s1.display()
# Out:
# Jay

# %% [markdown]
# ### Class Variables
#
# Class variables are shared among all objects of a class. They are defined inside the class but outside methods.

# %%
class Student:

    school = "ABC School"

print(Student.school)
# Out:
# ABC School

# %% [markdown]
# ### Encapsulation
#
# Encapsulation is the process of restricting direct access to data and allowing access through methods. It improves data security and control.

# %%
class Bank:

    def __init__(self):
        self.__balance = 1000

    def get_balance(self):
        return self.__balance

b = Bank()

print(b.get_balance())
# Out:
# 1000

# %% [markdown]
# ### Inheritance
#
# Inheritance allows one class to acquire properties and methods of another class. It promotes code reusability.

# %%
class Parent:

    def show(self):
        print("Parent")

class Child(Parent):
    pass

c = Child()
c.show()
# Out:
# Parent

# %% [markdown]
# ### Polymorphism
#
# Polymorphism allows the same method name to behave differently in different classes.

# %%
class Dog:

    def sound(self):
        print("Bark")

class Cat:

    def sound(self):
        print("Meow")

Dog().sound()
Cat().sound()
# Out:
# Bark
# Meow

# %% [markdown]
# ### Abstraction
#
# Abstraction hides implementation details and shows only essential features to the user.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

# %% [markdown]
# ### Method Overriding
#
# Method overriding occurs when a child class provides its own implementation of a method already defined in the parent class.

# %%
class Parent:

    def show(self):
        print("Parent Method")

class Child(Parent):

    def show(self):
        print("Child Method")

Child().show()
# Out:
# Child Method

# %% [markdown]
# ### super() Function
#
# The super() function allows a child class to access methods and constructors of its parent class.

# %%
class Parent:

    def __init__(self):
        print("Parent Constructor")

class Child(Parent):

    def __init__(self):
        super().__init__()
        print("Child Constructor")

Child()
# Out:
# Parent Constructor
# Child Constructor

# %% [markdown]
# ### Access Modifiers
#
# Python supports Public, Protected, and Private members. Public members can be accessed anywhere. Protected members use a single underscore. Private members use double underscores and are intended to be hidden.

# %%
class Demo:

    public = 10
    _protected = 20
    __private = 30

print(Demo.public)
# Out:
# 10

# %% [markdown]
# # Subtask

# %% [markdown]
# # 1. Create Classes and Objects

# %%
class Car:
    pass

c1 = Car()
print("Object Created")
# Out:
# Object Created

# %% [markdown]
# ## 2. Use Constructors

# %%
class Car:

    def __init__(self, brand):
        self.brand = brand

c = Car("BMW")
print(c.brand)
# Out:
# BMW

# %% [markdown]
# # 3. Define Attributes and Methods

# %%
class Car:

    def __init__(self, brand):
        self.brand = brand

    def show(self):
        print(self.brand)

Car("BMW").show()
# Out:
# BMW

# %% [markdown]
# ## 4. Implement Inheritance

# %%
class Animal:
    def sound(self):
        print("Animal Sound")

class Dog(Animal):
    pass

Dog().sound()
# Out:
# Animal Sound

# %% [markdown]
# # 5. Demonstrate Polymorphism

# %%
class Bird:
    def sound(self):
        print("Chirp")

class Duck:
    def sound(self):
        print("Quack")

Bird().sound()
Duck().sound()
# Out:
# Chirp
# Quack

# %% [markdown]
# # 6. Apply Encapsulation

# %%
class Account:

    def __init__(self):
        self.__balance = 1000

    def show(self):
        return self.__balance

print(Account().show())
# Out:
# 1000

# %% [markdown]
# # 7. Use Class And Instance Variables

# %%
class Student:

    school = "ABC"

    def __init__(self, name):
        self.name = name

s = Student("Jay")

print(Student.school)
print(s.name)
# Out:
# ABC
# Jay

# %% [markdown]
# # Practice Assignment

# %% [markdown]
# # Student Management System

# %%
class Student:

    def __init__(self, name, roll, marks):
        self.name = name
        self.roll = roll
        self.marks = marks

    def calculate_grade(self):

        if self.marks >= 90:
            return "A"
        elif self.marks >= 75:
            return "B"
        else:
            return "C"

    def display(self):

        print("Name:", self.name)
        print("Roll:", self.roll)
        print("Grade:", self.calculate_grade())

s = Student("Jay", 69, 85)

s.display()
# Out:
# Name: Jay
# Roll: 69
# Grade: B

# %% [markdown]
# # Bank Account System

# %%
class BankAccount:

    def __init__(self, balance):
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):

        if amount <= self.__balance:
            self.__balance -= amount

    def get_balance(self):
        return self.__balance

acc = BankAccount(1000)

acc.deposit(500)
acc.withdraw(200)

print(acc.get_balance())
# Out:
# 1300

# %% [markdown]
# # Employee Management

# %%
class Employee:

    def work(self):
        print("Employee Working")

class Manager(Employee):

    def manage(self):
        print("Managing Team")

m = Manager()

m.work()
m.manage()
# Out:
# Employee Working
# Managing Team

# %% [markdown]
# # Vehicle System

# %%
class Vehicle:

    def start(self):
        print("Vehicle Starts")

class Car(Vehicle):

    def start(self):
        print("Car Starts With Key")

class Bike(Vehicle):

    def start(self):
        print("Bike Starts With Self Start")

Car().start()
Bike().start()
# Out:
# Car Starts With Key
# Bike Starts With Self Start

# %% [markdown]
# # Shape Area Calculator

# %%
from abc import ABC, abstractmethod

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

class Rectangle(Shape):

    def __init__(self, l, b):
        self.l = l
        self.b = b

    def area(self):
        return self.l * self.b

r = Rectangle(10, 5)

print("Area:", r.area())
# Out:
# Area: 50

# %% [markdown]
# # Library Management System

# %%
class Library:

    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)

    def issue_book(self, book):

        if book in self.books:
            self.books.remove(book)

    def return_book(self, book):
        self.books.append(book)

    def display_books(self):
        print(self.books)

lib = Library()

lib.add_book("Python")
lib.add_book("Java")

lib.display_books()

lib.issue_book("Python")

lib.display_books()

lib.return_book("Python")

lib.display_books()
# Out:
# ['Python', 'Java']
# ['Java']
# ['Java', 'Python']

# %% [markdown]
# ## Conclusion
#
# In this assignment, I learned the fundamentals of Object-Oriented Programming including classes, objects, constructors, inheritance, polymorphism, encapsulation, abstraction, method overriding, access modifiers, and the super() function. I also implemented multiple OOP-based projects to understand reusable and scalable software design.
